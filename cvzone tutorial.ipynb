# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
color = cv2.imread("picture.png",cv2.IMREAD_COLOR)
print (color.dtype)
# Out:
# uint8

# %%
bit32 = cv2.imread("picture.png", cv2.IMREAD_ANYCOLOR | cv2.IMREAD_ANYDEPTH)
gray = cv2.imread("picture.png", 0)

# %%
cv2.imshow("Lena BGR", color)
cv2.imshow("Lena Gray", gray)
cv2.imshow("Lena 32", bit32)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
plt.imshow(gray)
plt.show()

# %%
gray_rgb = cv2.cvtColor(gray, cv2.COLOR_BGR2RGB)
plt.imshow(gray_rgb)

# %%
color_rgb = cv2.cvtColor(color, cv2.COLOR_BGR2RGB)
plt.imshow(color_rgb)

# %%
plt.imshow(bit32)

# %%
cv2.namedWindow("Lena Normal",cv2.WINDOW_NORMAL)
cv2.namedWindow("Lena Autosize",cv2.WINDOW_AUTOSIZE)
cv2.namedWindow("Lena Resized",cv2.WINDOW_NORMAL)
cv2.moveWindow("Lena Normal", 0, 0);
cv2.moveWindow("Lena Autosize", 220, 0)
cv2.moveWindow("Lena Resized", 440, 0)
cv2.resizeWindow("Lena Resized", 440, 440);
cv2.imshow("Lena Normal",color)
cv2.imshow("Lena Autosize",color)
cv2.imshow("Lena Resized",color)
cv2.waitKey(0)
cv2.destroyWindow("Lena Normal")
cv2.destroyWindow("Lena Autosize")
cv2.destroyWindow("Lena Resized")

# %%
pos=1
def onChange(pos):
    rail=cv2.imread("picture.png")
    cv2.imshow("Rail",rail)
    if (pos>0):
        rail = cv2.blur(rail,(pos,pos))
        cv2.imshow("Rail",rail)

# %%
cv2.namedWindow("Lena")
lena = cv2.createTrackbar("Blur","Lena",pos,15,onChange)
onChange(pos);
cv2.waitKey(0)
cv2.destroyAllWindows();

# %%
cap = cv2.VideoCapture(0)
color = (0,255,0)
line_width = 2
radius = 50
point = (0,0)

def onMouse(event, x, y, flags, param):
    global point, pressed
    if event == cv2.EVENT_LBUTTONDOWN:
        print("Pressed",x,y)
        point = (x,y)

# %%
cv2.namedWindow("Frame")
cv2.setMouseCallback("Frame", onMouse)
while(True):
    ret, frame = cap.read()
    frame = cv2.resize(frame, (0,0), fx=1,fy=1)
    cv2.circle(frame, point, radius, color, line_width) 
    cv2.imshow("Frame",frame)
    ch = cv2.waitKey(1)
    if ch & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# Pressed 380 307
# Pressed 480 381
